# %% [markdown]
# # ACPC distance calculations
# Sandy Wong 2022-01-26

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import csv
import math
import os

# %% [markdown]
# ### Functions

# %% [markdown]
# #### Get data from fcsv and put in dictionary

# %%
def getDataFromFcsv(inFile): #inFile = fcsv with annotation data 

    version = 0
    coordSys = ""
    cols = []
    data = []

    with open(inFile, newline='') as csvfile:
        csvreader = csv.reader(csvfile, delimiter=' ')
        for row in csvreader:
            if row[0] == "#": #header in fcsv
                if row[1] == "Markups":
                    version = float(row[-1])
                if row[1] == "CoordinateSystem":
                    coordSys = str(row[-1])
                if row[1] == "columns":
                    cols = row[-1].split(",")

            else:  #data in fcsv
                rawdata = row[0].split(",")
                data.append(rawdata)
    
    df = pd.DataFrame(data, columns = cols )
    
    data_dict = {"version":version,
                 "coordinateSystem": coordSys,
                 "data":df}
    
    return data_dict

# %% [markdown]
# #### Get distance between 2 points

# %%
def getDistance(label1, label2, col, df):
    
    row1 = df.loc[df[col]==label1]
    row2 = df.loc[df[col]==label2]
    
    dist = math.sqrt((float(row1["x"])-float(row2["x"]))**2 + 
                     (float(row1["y"])-float(row2["y"]))**2 +
                     (float(row1["z"])-float(row2["z"]))**2)
    return(dist)

# %% [markdown]
# ### Loop through filenames and get ACPC distance for all

# %% [markdown]
# #### Filenames

# %%
path_AFIDs_Clinical = "C:\\Users\\Sandy\\Documents\\AFIDs-Data\\AFIDs-Clinical"
path_OASIS_DATASET = "C:\\Users\\Sandy\\Documents\\AFIDs-Data\\OASIS-DATASET"
#HCP_DATASET
path_SNSX_DATASET = "C:\\Users\\Sandy\\Documents\\AFIDs-Data\\SNSX-DATASET"

files_AFIDs_Clinical = os.listdir(path_AFIDs_Clinical)
files_OASIS_DATASET = os.listdir(path_OASIS_DATASET)
files_SNSX_DATASET = os.listdir(path_SNSX_DATASET)

# %% [markdown]
# #### Looping through all the files and calculating ACPC dist

# %% [markdown]
# ##### AFIDs-Clinical

# %%
ACPC_dists_AFIDs_Clinical = []
for folder in files_AFIDs_Clinical:
    file = "%s/%s/%s_FID32_T1w_mean.fcsv" % ("AFIDs-Clinical",folder,folder)
    data = getDataFromFcsv(file)
    ACPC_dist = getDistance("AC","PC","label",data["data"])
    
    fileshort = file.split("/")[-1]
    ACPC_dists_AFIDs_Clinical.append(["AFIDs-Clinical",fileshort,ACPC_dist])
    
AFIDs_Clinical_ACPC = pd.DataFrame(ACPC_dists_AFIDs_Clinical, columns = ["dataset","filename","ACPC_dist"] )

# %%
AFIDs_Clinical_ACPC
# Out:
#            dataset                     filename  ACPC_dist
# 0   AFIDs-Clinical  sub-087_FID32_T1w_mean.fcsv  22.461212
# 1   AFIDs-Clinical  sub-093_FID32_T1w_mean.fcsv  30.791855
# 2   AFIDs-Clinical  sub-103_FID32_T1w_mean.fcsv  24.639562
# 3   AFIDs-Clinical  sub-106_FID32_T1w_mean.fcsv  26.582287
# 4   AFIDs-Clinical  sub-107_FID32_T1w_mean.fcsv  25.573500
# 5   AFIDs-Clinical  sub-113_FID32_T1w_mean.fcsv  27.239744
# 6   AFIDs-Clinical  sub-115_FID32_T1w_mean.fcsv  27.588931
# 7   AFIDs-Clinical  sub-116_FID32_T1w_mean.fcsv  27.100211
# 8   AFIDs-Clinical  sub-118_FID32_T1w_mean.fcsv  23.945167
# 9   AFIDs-Clinical  sub-120_FID32_T1w_mean.fcsv  28.424207
# 10  AFIDs-Clinical  sub-122_FID32_T1w_mean.fcsv  27.889699
# 11  AFIDs-Clinical  sub-124_FID32_T1w_mean.fcsv  26.560610
# 12  AFIDs-Clinical  sub-125_FID32_T1w_mean.fcsv  25.847204
# 13  AFIDs-Clinical  sub-126_FID32_T1w_mean.fcsv  27.908702
# 14  AFIDs-Clinical  sub-127_FID32_T1w_mean.fcsv  26.684092
# 15  AFIDs-Clinical  sub-128_FID32_T1w_mean.fcsv  27.116671
# 16  AFIDs-Clinical  sub-131_FID32_T1w_mean.fcsv  26.300395
# 17  AFIDs-Clinical  sub-132_FID32_T1w_mean.fcsv  27.491100
# 18  AFIDs-Clinical  sub-133_FID32_T1w_mean.fcsv  30.905759
# 19  AFIDs-Clinical  sub-135_FID32_T1w_mean.fcsv  29.683110
# 20  AFIDs-Clinical  sub-136_FID32_T1w_mean.fcsv  29.358918
# 21  AFIDs-Clinical  sub-138_FID32_T1w_mean.fcsv  25.437066
# 22  AFIDs-Clinical  sub-139_FID32_T1w_mean.fcsv  25.855770
# 23  AFIDs-Clinical  sub-141_FID32_T1w_mean.fcsv  26.268805
# 24  AFIDs-Clinical  sub-145_FID32_T1w_mean.fcsv  26.556103
# 25  AFIDs-Clinical  sub-146_FID32_T1w_mean.fcsv  27.372538
# 26  AFIDs-Clinical  sub-147_FID32_T1w_mean.fcsv  25.873693
# 27  AFIDs-Clinical  sub-148_FID32_T1w_mean.fcsv  25.304338
# 28  AFIDs-Clinical  sub-149_FID32_T1w_mean.fcsv  26.827191
# 29  AFIDs-Clinical  sub-150_FID32_T1w_mean.fcsv  27.323008
# 30  AFIDs-Clinical  sub-151_FID32_T1w_mean.fcsv  25.257437
# 31  AFIDs-Clinical  sub-152_FID32_T1w_mean.fcsv  24.625014
# 32  AFIDs-Clinical  sub-153_FID32_T1w_mean.fcsv  28.249171
# 33  AFIDs-Clinical  sub-156_FID32_T1w_mean.fcsv  27.209532
# 34  AFIDs-Clinical  sub-157_FID32_T1w_mean.fcsv  27.172757
# 35  AFIDs-Clinical  sub-158_FID32_T1w_mean.fcsv  26.760759
# 36  AFIDs-Clinical  sub-161_FID32_T1w_mean.fcsv  27.371007
# 37  AFIDs-Clinical  sub-162_FID32_T1w_mean.fcsv  24.239807
# 38  AFIDs-Clinical  sub-163_FID32_T1w_mean.fcsv  26.661558
# 39  AFIDs-Clinical  sub-168_FID32_T1w_mean.fcsv  27.547259

# %% [markdown]
# ###### Group calculations

# %%
ACPC_dists = np.array(AFIDs_Clinical_ACPC["ACPC_dist"].tolist())

# %%
mean = np.mean(ACPC_dists)
stddev = np.std(ACPC_dists)
print("AFIDs-Clincical:\nmean: %0.10f\nstandard deviation: %0.10f" % (mean, stddev))
# Out:
# AFIDs-Clincical:
# mean: 26.8001437626
# standard deviation: 1.6761420771

# %% [markdown]
# ##### OASIS-DATASET

# %%
ACPC_dists_OASIS_DATASET = []
for file in files_OASIS_DATASET:
    filePath = "%s/%s" % ("OASIS-DATASET",file)
    data = getDataFromFcsv(filePath)
    ACPC_dist = getDistance("AC","PC","desc",data["data"])
    ACPC_dists_OASIS_DATASET.append(["OASIS-DATASET",file,ACPC_dist])
    
OASIS_DATASET_ACPC = pd.DataFrame(ACPC_dists_OASIS_DATASET, columns = ["dataset","filename","ACPC_dist"] )

# %%
OASIS_DATASET_ACPC
# Out:
#           dataset                    filename  ACPC_dist
# 0   OASIS-DATASET  OAS1_0010_MR1_T1_MEAN.fcsv  27.214280
# 1   OASIS-DATASET  OAS1_0086_MR1_T1_MEAN.fcsv  26.314230
# 2   OASIS-DATASET  OAS1_0101_MR1_T1_MEAN.fcsv  26.785988
# 3   OASIS-DATASET  OAS1_0109_MR1_T1_MEAN.fcsv  24.287715
# 4   OASIS-DATASET  OAS1_0114_MR1_T1_MEAN.fcsv  26.133480
# 5   OASIS-DATASET  OAS1_0117_MR1_T1_MEAN.fcsv  24.887766
# 6   OASIS-DATASET  OAS1_0145_MR1_T1_MEAN.fcsv  26.001447
# 7   OASIS-DATASET  OAS1_0177_MR1_T1_MEAN.fcsv  27.141188
# 8   OASIS-DATASET  OAS1_0180_MR1_T1_MEAN.fcsv  27.498105
# 9   OASIS-DATASET  OAS1_0188_MR1_T1_MEAN.fcsv  25.846434
# 10  OASIS-DATASET  OAS1_0200_MR1_T1_MEAN.fcsv  24.953192
# 11  OASIS-DATASET  OAS1_0203_MR1_T1_MEAN.fcsv  26.051904
# 12  OASIS-DATASET  OAS1_0216_MR1_T1_MEAN.fcsv  24.567581
# 13  OASIS-DATASET  OAS1_0239_MR1_T1_MEAN.fcsv  27.947590
# 14  OASIS-DATASET  OAS1_0249_MR1_T1_MEAN.fcsv  24.781456
# 15  OASIS-DATASET  OAS1_0255_MR1_T1_MEAN.fcsv  26.759416
# 16  OASIS-DATASET  OAS1_0256_MR1_T1_MEAN.fcsv  27.234807
# 17  OASIS-DATASET  OAS1_0263_MR1_T1_MEAN.fcsv  29.354668
# 18  OASIS-DATASET  OAS1_0266_MR1_T1_MEAN.fcsv  28.762541
# 19  OASIS-DATASET  OAS1_0274_MR1_T1_MEAN.fcsv  24.822615
# 20  OASIS-DATASET  OAS1_0284_MR1_T1_MEAN.fcsv  26.575979
# 21  OASIS-DATASET  OAS1_0303_MR1_T1_MEAN.fcsv  23.429517
# 22  OASIS-DATASET  OAS1_0343_MR1_T1_MEAN.fcsv  26.420402
# 23  OASIS-DATASET  OAS1_0345_MR1_T1_MEAN.fcsv  25.962811
# 24  OASIS-DATASET  OAS1_0357_MR1_T1_MEAN.fcsv  25.950092
# 25  OASIS-DATASET  OAS1_0365_MR1_T1_MEAN.fcsv  26.307155
# 26  OASIS-DATASET  OAS1_0371_MR1_T1_MEAN.fcsv  26.425847
# 27  OASIS-DATASET  OAS1_0395_MR1_T1_MEAN.fcsv  26.988376
# 28  OASIS-DATASET  OAS1_0398_MR1_T1_MEAN.fcsv  29.476370
# 29  OASIS-DATASET  OAS1_0456_MR1_T1_MEAN.fcsv  27.008634

# %% [markdown]
# ###### Group calculations

# %%
ACPC_dists = np.array(OASIS_DATASET_ACPC["ACPC_dist"].tolist())

# %%
mean = np.mean(ACPC_dists)
stddev = np.std(ACPC_dists)
print("OASIS-DATASET:\nmean: %0.10f\nstandard deviation: %0.10f" % (mean, stddev))
# Out:
# OASIS-DATASET:
# mean: 26.3963861472
# standard deviation: 1.3845644721

# %% [markdown]
# ##### SNSX-DATASET

# %%
ACPC_dists_SNSX_DATASET = []
for file in files_SNSX_DATASET:
    filePath = "%s/%s" % ("SNSX-DATASET",file)
    data = getDataFromFcsv(filePath)
    ACPC_dist = getDistance("AC","PC","desc",data["data"])
    ACPC_dists_SNSX_DATASET.append(["SNSX-DATASET",file,ACPC_dist])
    
SNSX_DATASET_ACPC = pd.DataFrame(ACPC_dists_SNSX_DATASET, columns = ["dataset","filename","ACPC_dist"] )

# %%
SNSX_DATASET_ACPC
# Out:
#          dataset             filename  ACPC_dist
# 0   SNSX-DATASET  sub-C001_afids.fcsv  26.518466
# 1   SNSX-DATASET  sub-C002_afids.fcsv  25.905931
# 2   SNSX-DATASET  sub-C003_afids.fcsv  26.969073
# 3   SNSX-DATASET  sub-C004_afids.fcsv  27.492744
# 4   SNSX-DATASET  sub-C005_afids.fcsv  25.088048
# 5   SNSX-DATASET  sub-C006_afids.fcsv  26.450426
# 6   SNSX-DATASET  sub-C007_afids.fcsv  25.647685
# 7   SNSX-DATASET  sub-C008_afids.fcsv  25.653567
# 8   SNSX-DATASET  sub-C009_afids.fcsv  26.163060
# 9   SNSX-DATASET  sub-C010_afids.fcsv  24.342161
# 10  SNSX-DATASET  sub-C011_afids.fcsv  26.468370
# 11  SNSX-DATASET  sub-C012_afids.fcsv  25.050437
# 12  SNSX-DATASET  sub-C013_afids.fcsv  27.460222
# 13  SNSX-DATASET  sub-C015_afids.fcsv  26.030394
# 14  SNSX-DATASET  sub-C016_afids.fcsv  25.073317
# 15  SNSX-DATASET  sub-C018_afids.fcsv  25.163166
# 16  SNSX-DATASET  sub-C019_afids.fcsv  25.582675
# 17  SNSX-DATASET  sub-C020_afids.fcsv  26.973845
# 18  SNSX-DATASET  sub-C021_afids.fcsv  27.208302
# 19  SNSX-DATASET  sub-C022_afids.fcsv  27.512582
# 20  SNSX-DATASET  sub-C023_afids.fcsv  26.463747
# 21  SNSX-DATASET  sub-C024_afids.fcsv  25.100186
# 22  SNSX-DATASET  sub-C025_afids.fcsv  27.521165
# 23  SNSX-DATASET  sub-C026_afids.fcsv  25.699890
# 24  SNSX-DATASET  sub-C027_afids.fcsv  23.550879
# 25  SNSX-DATASET  sub-C028_afids.fcsv  27.256798
# 26  SNSX-DATASET  sub-C029_afids.fcsv  29.283634
# 27  SNSX-DATASET  sub-C030_afids.fcsv  28.173064
# 28  SNSX-DATASET  sub-C031_afids.fcsv  27.043737
# 29  SNSX-DATASET  sub-C032_afids.fcsv  26.275807
# 30  SNSX-DATASET  sub-C033_afids.fcsv  26.948186
# 31  SNSX-DATASET  sub-C034_afids.fcsv  25.035887

# %% [markdown]
# #### Group calculations

# %%
ACPC_dists = np.array(SNSX_DATASET_ACPC["ACPC_dist"].tolist())

# %%
mean = np.mean(ACPC_dists)
stddev = np.std(ACPC_dists)
print("SNSX-DATASET:\nmean: %0.10f\nstandard deviation: %0.10f" % (mean, stddev))
# Out:
# SNSX-DATASET:
# mean: 26.2846079199
# standard deviation: 1.1738735344

# %% [markdown]
# ## AFLEs

# %% [markdown]
# #### SNSX

# %% [markdown]
# ##### Get coordinates of fidfucials and put in dataframe

# %%
fiducials_SNSX_DATASET = {}
for file in files_SNSX_DATASET:
    filePath = "%s/%s" % ("SNSX-DATASET",file)
    data = getDataFromFcsv(filePath)
    fData = data["data"]
    
    for fid_label in range(1,33):
                
        xCoord = float(fData.loc[fData["label"]==str(fid_label)]["x"])
        yCoord = float(fData.loc[fData["label"]==str(fid_label)]["y"])
        zCoord = float(fData.loc[fData["label"]==str(fid_label)]["z"])
        
        if fid_label not in fiducials_SNSX_DATASET:
            fiducials_SNSX_DATASET[fid_label] = []
        fiducials_SNSX_DATASET[fid_label].append([xCoord, yCoord, zCoord])

# %% [markdown]
# ##### Calculate mean, then calculate dist from mean, from this sample calculate distribution

# %%
mean_fiducials_SNSX_DATASET = {}
for fid_label in range(1,33):
    coordinates = fiducials_SNSX_DATASET[fid_label]
    xMean = np.mean([coords[0] for coords in coordinates])
    yMean = np.mean([coords[1] for coords in coordinates])
    zMean = np.mean([coords[2] for coords in coordinates])
    
    if fid_label not in mean_fiducials_SNSX_DATASET:
        mean_fiducials_SNSX_DATASET[fid_label] = [xMean, yMean, zMean]
    else:
        print("already in the ds")

# %%
### Distance from x coord mean
AFLE_SNSX_DATASET = {}
for fid_label in range(1,2):
    
    xMean = mean_fiducials_SNSX_DATASET[fid_label][0]
    yMean = mean_fiducials_SNSX_DATASET[fid_label][1]
    zMean = mean_fiducials_SNSX_DATASET[fid_label][2]
    
    coordinates = fiducials_SNSX_DATASET[fid_label]
    diffs = [math.sqrt((coords[0]-xMean)**2 + (coords[1]-yMean)**2 + (coords[2]-zMean)**2) for coords in coordinates]
    
    if fid_label not in AFLE_SNSX_DATASET:
        AFLE_SNSX_DATASET[fid_label] = diffs
    else:
        print("already in ds")

# %%
AFLE_SNSX_DATASET
# Out:
# {1: [13.249489543097997,
#   14.49426542656928,
#   5.113082281836308,
#   10.82464616800237,
#   5.541904971729708,
#   10.559507431530754,
#   24.99964255425079,
#   11.814692574429488,
#   9.476500952966289,
#   20.292537286322425,
#   4.333643124921317,
#   7.77001295305446,
#   9.1747842856971,
#   18.306115601204656,
#   12.146003496164628,
#   12.301376923321461,
#   4.2195213616207905,
#   5.504423693170148,
#   15.237440378432474,
#   13.971221090928582,
#   2.8690168526905384,
#   7.8942806337096805,
#   10.530827368740349,
#   11.353516924589664,
#   8.458881569231293,
#   13.41023358100189,
#   19.67995513163593,
#   8.065230722711792,
#   9.425272491968691,
#   9.745553647922522,
#   14.59898241944546,
#   15.235801482511848],
#  2: [12.779129754189311,
#   20.22283323332583,
#   7.163625767475787,
#   10.92920810513938,
#   7.856170623079633,
#   11.949805737563933,
#   27.036060791807987,
#   8.655473792414433,
